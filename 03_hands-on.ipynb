# %%
import pandas as pd
import numpy as np
import seaborn as sns

print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("seaborn:", sns.__version__)
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# pandas: 1.5.1
# numpy: 1.22.4
# seaborn: 0.12.0

# %% [markdown]
# # bike-rental dataset
#
# https://www.kaggle.com/datasets/archit9406/bike-sharing?select=hour.csv

# %% [markdown]
# - Duration – Duration of trip
# - Start Date – Includes start date and time
# - End Date – Includes end date and time
# - Start Station – Includes starting station name and number
# - End Station – Includes ending station name and number
# - Bike Number – Includes ID number of bike used for the trip
# - Member Type – Indicates whether user was a "registered" member (Annual Member, 30-Day Member or Day Key Member) or a "casual" rider (Single Trip, 24-Hour Pass, 3-Day Pass or 5-Day Pass)

# %%
data = "data/bike-rental.csv"
df = pd.read_csv(data)

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df["hr"].astype(str).str.rjust(width=2, fillchar="0")
# Out:
# 0        00
# 1        01
# 2        02
# 3        03
# 4        04
#          ..
# 17374    19
# 17375    20
# 17376    21
# 17377    22
# 17378    23
# Name: hr, Length: 17379, dtype: object

# %%
df.groupby("dteday").cnt.sum().plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='dteday'>

# %%
sns.boxplot(data=df, x="mnth", y="cnt")
# Out:
# <AxesSubplot:xlabel='mnth', ylabel='cnt'>

# %%
sns.lineplot(data=df, x="dteday", y="cnt")
# Out:
# <AxesSubplot:xlabel='dteday', ylabel='cnt'>

# %%
df["dt"] = pd.to_datetime(df["dteday"] + " " + df["hr"].astype(str).str.rjust(width=2, fillchar="0"), format="%Y-%m-%d %H")

# %%
df = df.set_index("dt")

# %%
sns.lineplot(data=df, x="dt", y="cnt")
# Out:
# <AxesSubplot:xlabel='dt', ylabel='cnt'>

# %% [markdown]
# # The Movies Dataset
#
# https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset?select=credits.csv

# %%
metadata = "data/movies_metadata.csv"
df_metadata = pd.read_csv(metadata)
# Out:
# <ipython-input-69-dbe724c3c875>:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_metadata = pd.read_csv(metadata)

# %%
df_metadata
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
keywords = "data/keywords.csv"
df_keywords = pd.read_csv(keywords)

# %%
df_keywords.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
df_metadata[-df_metadata.id.str.isnumeric()]
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# ...

# %%
df_metadata = df_metadata[df_metadata.id.str.isnumeric()]

# %%
df_metadata.loc[:, "id"] = df_metadata["id"].astype(int)
# Out:
# <ipython-input-89-582ad9f888a2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metadata.loc[:, "id"] = df_metadata["id"].astype(int)

# %%
df_movies = pd.merge(df_metadata, df_keywords, on="id")

# %%
df_movies.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.json_normalize.html

# %%
pd.json_normalize(df_movies["genres"].values, record_path="name")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-5547fc8edde2> in <module>
# ----> 1 pd.json_normalize(df_movies["genres"].values, record_path="name")
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     516                 records.extend(recs)
#     517
# --> 518     _recursive_extract(data, record_path, {}, level=0)
#     519
#     520     result = DataFrame(records)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\json\_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     498         else:
#     499             for obj in data:
# --> 500                 recs = _pull_records(obj, path[0])
#     501                 recs = [
# ...

# %%
import json

json.loads(df_movies["genres"][0])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-103-299bc138318b> in <module>
#       1 import json
#       2
# ----> 3 json.loads(df_movies["genres"][0])
#
# c:\tools\miniconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# c:\tools\miniconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ...

# %%
pd.json_normalize(json.loads(df_movies["genres"][0].replace("'", "\"")))
# Out:
#       id       name
# 0     16  Animation
# 1     35     Comedy
# 2  10751     Family

# %%
def parse_genre(line: str):
    line = line.replace("'", "\"")
    line = json.loads(line)
    df_genre = pd.json_normalize(line)
    if not df_genre.empty:
        names = ",".join(df_genre["name"])
    else:
        names = ""
        
    return names

df_movies["genres"].apply(parse_genre)
# Out:
# 0         Animation,Comedy,Family
# 1        Adventure,Fantasy,Family
# 2                  Romance,Comedy
# 3            Comedy,Drama,Romance
# 4                          Comedy
#                    ...
# 46477                Drama,Family
# 46478                       Drama
# 46479       Action,Drama,Thriller
# 46480
# 46481
# Name: genres, Length: 46482, dtype: object
